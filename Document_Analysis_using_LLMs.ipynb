# %% [markdown]
# <a href="https://colab.research.google.com/github/mukulre/Projects/blob/main/Document_Analysis_using_LLMs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pdfplumber
# Out:
# Collecting pdfplumber
#   Downloading pdfplumber-0.11.5-py3-none-any.whl.metadata (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.5/42.5 kB 1.7 MB/s eta 0:00:00
# Collecting pdfminer.six==20231228 (from pdfplumber)
#   Downloading pdfminer.six-20231228-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: Pillow>=9.1 in /usr/local/lib/python3.10/dist-packages (from pdfplumber) (11.0.0)
# Collecting pypdfium2>=4.18.0 (from pdfplumber)
#   Downloading pypdfium2-4.30.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six==20231228->pdfplumber) (3.4.0)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six==20231228->pdfplumber) (43.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (2.22)
# Downloading pdfplumber-0.11.5-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 4.3 MB/s eta 0:00:00
# Downloading pdfminer.six-20231228-py3-none-any.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 50.9 MB/s eta 0:00:00
# Downloading pypdfium2-4.30.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 64.6 MB/s eta 0:00:00
# Installing collected packages: pypdfium2, pdfminer.six, pdfplumber
# Successfully installed pdfminer.six-20231228 pdfplumber-0.11.5 pypdfium2-4.30.1

# %%
import pdfplumber

pdf_path = "/content/google_terms_of_service_en_in.pdf"

output_text_file = "extracted_text.txt"

with pdfplumber.open(pdf_path) as pdf:
    extracted_text = ""
    for page in pdf.pages:
        extracted_text += page.extract_text()

with open(output_text_file, "w") as text_file:
    text_file.write(extracted_text)

print(f"Text extracted and saved to {output_text_file}")
# Out:
# Text extracted and saved to extracted_text.txt

# %%
# reading pdf content
with open("/content/extracted_text.txt", "r") as file:
    document_text = file.read()

# preview the document content
print(document_text[:500])  # preview the first 500 characters
# Out:
# GOOGLE TERMS OF SERVICE
# Effective May 22, 2024 | Archived versions
# What’s covered in these terms
# We know it’s tempting to skip these Terms of
# Service, but it’s important to establish what you
# can expect from us as you use Google services,
# and what we expect from you.
# These Terms of Service reect the way Google’s business works, the laws that apply to
# our company, and certain things we’ve always believed to be true. As a result, these Terms
# of Service help dene Google’s relationship with you as

# %%
from transformers import pipeline

# load the summarization pipeline
summarizer = pipeline("summarization", model="t5-small")

# summarize the document text (you can summarize parts if the document is too large)
summary = summarizer(document_text[:1000], max_length=150, min_length=30, do_sample=False)
print("Summary:", summary[0]['summary_text'])
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/242M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/2.32k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# Device set to use cpu
# Summary: these Terms of Service reect the way Google’s business works, the laws that apply to our company, and certain things we’ve always believed to be true . these terms include: what you can expect from us, which describes how we provide and develop our services What we expect from you, which establishes certain rules for using our services Content in Google services .

# %%
import nltk

try:
    sentences = nltk.sent_tokenize(document_text)
except LookupError:
    print("Downloading 'punkt_tab' data...")
    nltk.download('punkt_tab')
    sentences = nltk.sent_tokenize(document_text)

# combine sentences into passages
passages = []
current_passage = ""
for sentence in sentences:
    if len(current_passage.split()) + len(sentence.split()) < 20:  # adjust the word limit as needed
        current_passage += " " + sentence
    else:
        passages.append(current_passage.strip())
        current_passage = sentence
if current_passage:
    passages.append(current_passage.strip())
# Out:
# Downloading 'punkt_tab' data...
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
# load the question generation pipeline
qg_pipeline = pipeline("text2text-generation", model="valhalla/t5-base-qg-hl")

# function to generate questions using the pipeline
def generate_questions_pipeline(passage, min_questions=3):
    input_text = f"generate questions: {passage}"
    results = qg_pipeline(input_text)
    questions = results[0]['generated_text'].split('<sep>')

    # ensure we have at least 3 questions
    questions = [q.strip() for q in questions if q.strip()]

    # if fewer than 3 questions, try to regenerate from smaller parts of the passage
    if len(questions) < min_questions:
        passage_sentences = passage.split('. ')
        for i in range(len(passage_sentences)):
            if len(questions) >= min_questions:
                break
            additional_input = ' '.join(passage_sentences[i:i+2])
            additional_results = qg_pipeline(f"generate questions: {additional_input}")
            additional_questions = additional_results[0]['generated_text'].split('<sep>')
            questions.extend([q.strip() for q in additional_questions if q.strip()])

    return questions[:min_questions]  # return only the top 3 questions

# generate questions from passages
for idx, passage in enumerate(passages):
    questions = generate_questions_pipeline(passage)
    print(f"Passage {idx+1}:\n{passage}\n")
    print("Generated Questions:")
    for q in questions:
        print(f"- {q}")
    print(f"\n{'-'*50}\n")
# Out:
# config.json:   0%|          | 0.00/1.02k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/892M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/129 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/15.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/1.79k [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# Device set to use cpu
# Passage 1:
#
#
# Generated Questions:
# - What is the name of the question that is asked?
# - What is the name of the question that is asked?
#
# --------------------------------------------------
#
# Passage 2:
# GOOGLE TERMS OF SERVICE
# Effective May 22, 2024 | Archived versions
# What’s covered in these terms
# We know it’s tempting to skip these Terms of
# Service, but it’s important to establish what you
# can expect from us as you use Google services,
# and what we expect from you.
#
# Generated Questions:
# - What is the term for the Google Terms of Service?
# - What is the term for the Google Terms of Service?
#
# --------------------------------------------------
#
# Passage 3:
# These Terms of Service reect the way Google’s business works, the laws that apply to
# our company, and certain things we’ve always believed to be true.
#
# Generated Questions:
# - What are the Terms of Service?
# - What are the Terms of Service?
#
# --------------------------------------------------
#
# Passage 4:
# As a result, these Terms
# of Service help dene Google’s relationship with you as you interact with our services.
#
# Generated Questions:
# - What are the Terms of Service?
# - What are the Terms of Service?
#
# --------------------------------------------------
#
# Passage 5:
# For
# example, these terms include the following topic headings:
# What you can expect from us, which describes how we provide and develop our
# services
# What we expect from you, which establishes certain rules for using our services
# Content in Google services, which describes the intellectual property rights to the
# content you nd in our services — whether that content belongs to you, Google, or
# others
# In case of problems or disagreements, which describes other legal rights you have,
# and what to expect in case someone violates these terms
# Understanding these terms is important because, by accessing or using our services,
# you’re agreeing to these terms.
#
# Generated Questions:
# - What does the term "What you can expect from us" mean?
# - What does the term "What you can expect from us" mean?
#
# --------------------------------------------------
#
# Passage 6:
# Besides these terms, we also publish a Privacy Policy.
#
# Generated Questions:
# - What is the Privacy Policy?
# - What is the Privacy Policy?
#
# --------------------------------------------------
#
# Passage 7:
# Although it’s not part of these
# terms, we encourage you to read it to better understand how you can update, manage,
# export, and delete your information.Terms
# Service provider
# Google services are provided by, and you’re contracting with:
# Google LLC
# organized under the laws of the State of Delaware, USA, and operating under the laws of
# the USA
# 1600 Amphitheatre Parkway
# Mountain View, California 94043
# USA
# Age requirements
# If you’re under the age required to manage your own Google Account, you must have
# your parent or legal guardian’s permission to use a Google Account.
#
# Generated Questions:
# - What is the name of the company that provides Google services?
# - What is the name of the company that provides Google services?
#
# --------------------------------------------------
#
# Passage 8:
# Please have your
# parent or legal guardian read these terms with you.
#
# Generated Questions:
# - What do you need to do to read the terms?
# - What do you need to do to read the terms?
#
# --------------------------------------------------
#
# Passage 9:
# If you’re a parent or legal guardian, and you allow your child to use the services, then
# these terms apply to you and you’re responsible for your child’s activity on the services.
#
# Generated Questions:
# - What are the terms of service for parents and guardians?
# - What are the terms of service for parents and guardians?
#
# --------------------------------------------------
#
# Passage 10:
# Some Google services have additional age requirements as described in their service-
# specic additional terms and policies.
#
# Generated Questions:
# - What is the age requirement for some services?
# - What is the age requirement for some services?
#
# --------------------------------------------------
#
# Passage 11:
# Your relationship with GoogleThese terms help dene the relationship between you and Google.
#
# Generated Questions:
# - What terms help delineate the relationship between you and Google?
# - What terms help delineate the relationship between you and Google?
#
# --------------------------------------------------
#
# Passage 12:
# When we speak of
# “Google,” “we,” “us,” and “our,” we mean Google LLC and its aliates, excluding any local
# entities based in India.
#
# Generated Questions:
# - What does Google mean by Google LLC?
# - What does Google mean by Google LLC?
#
# --------------------------------------------------
#
# Passage 13:
# Broadly speaking, we give you permission to access and use our
# services if you agree to follow these terms, which reect how Google’s business works
# and how we earn money.
#
# Generated Questions:
# - What are the terms of Google's business?
# - What are the terms of Google's business?
#
# --------------------------------------------------
#
# Passage 14:
# What you can expect from us
# Provide a broad range of useful services
# We provide a broad range of services that are subject to these terms, including:
# apps and sites (like Search and Maps)
# platforms (like Google Shopping)
# integrated services (like Maps embedded in other companies’ apps or sites)
# devices (like Google Nest and Pixel)
# Many of these services also include content that you can stream or interact with.
#
# Generated Questions:
# - What kind of services do you expect from Google?
# - What kind of services do you expect from Google?
#
# --------------------------------------------------
#
# Passage 15:
# Our services are designed to work together, making it easier for you to move from one
# activity to the next.
#
# Generated Questions:
# - What is the purpose of our services?
# - What is the purpose of our services?
#
# --------------------------------------------------
#
# Passage 16:
# For example, if your Calendar event includes an address, you can click
# on that address and Maps can show you how to get there.
#
# Generated Questions:
# - What can Maps show you how to get to an address?
# - What can Maps show you how to get to an address?
#
# --------------------------------------------------
#
# Passage 17:
# Develop, improve, and update Google services
# We’re constantly developing new technologies and features to improve our services.
#
# Generated Questions:
# - What is the purpose of the Google services?
# - What is the purpose of the Google services?
#
# --------------------------------------------------
#
# Passage 18:
# For
# example, we use articial intelligence and machine learning to provide you with
# simultaneous translations, and to better detect and block spam and malware.
#
# Generated Questions:
# - What do we use to provide you with simultaneous translations?
# - What do we use to provide you with simultaneous translations?
#
# --------------------------------------------------
#
# Passage 19:
# As part of
# this continual improvement, we sometimes add or remove features and functionalities,
# increase or decrease limits to our services, and start offering new services or stop offering
# old ones.
#
# Generated Questions:
# - What does it mean to add or remove features and functionalities?
# - What does it mean to add or remove features and functionalities?
#
# --------------------------------------------------
#
# Passage 20:
# When a service requires or includes downloadable or preloaded software, that
# software sometimes updates automatically on your device once a new version or feature
# is available.
#
# Generated Questions:
# - What happens when a service requires or includes downloadable or preloaded software?
# - What happens when a service requires or includes downloadable or preloaded software?
#
# --------------------------------------------------
#
# Passage 21:
# Some services let you adjust your automatic update settings.If we make material changes that negatively impact your use of our services or if we stop
# offering a service, we’ll provide you with reasonable advance notice, except in urgent
# situations such as preventing abuse, responding to legal requirements, or addressing
# security and operability issues.
#
# Generated Questions:
# - What is the name of the service that lets you adjust your automatic update settings?
# - What is the name of the service that lets you adjust your automatic update settings?
#
# --------------------------------------------------
#
# Passage 22:
# We’ll also provide you with an opportunity to export your
# content from your Google Account using Google Takeout, subject to applicable law and
# policies.
#
# Generated Questions:
# - What is the legal requirement for Google Takeout?
# - What is the legal requirement for Google Takeout?
#
# --------------------------------------------------
#
# Passage 23:
# What we expect from you
# Follow these terms and service-specic additional terms
# The permission we give you to access and use our services continues as long as you
# comply with:
# these terms
# service-specic additional terms, which could, for example, include things like
# additional age requirements
# We also make various policies, help centers, and other resources available to you to
# answer common questions and to set expectations about using our services.
#
# Generated Questions:
# - What are the terms that we expect from you?
# - What are the terms that we expect from you?
#
# --------------------------------------------------
#
# Passage 24:
# These
# resources include our Privacy Policy, Copyright Help Center, Safety Center, Transparency
# Center,and other pages accessible from our policies site.
#
# Generated Questions:
# - What resources are available from our policies site?
# - What resources are available from our policies site?
#
# --------------------------------------------------
#
# Passage 25:
# Finally, we may provide specic
# instructions and warnings within our services – such as dialog boxes that alert you to
# important information.
#
# Generated Questions:
# - What do we provide to you in our services?
# - What do we provide to you in our services?
#
# --------------------------------------------------
#
# Passage 26:
# Although we give you permission to use our services, we retain any intellectual property
# rights we have in the services.
#
# Generated Questions:
# - What does the term "intellectual property" mean?
# - What does the term "intellectual property" mean?
#
# --------------------------------------------------
#
# Passage 27:
# Respect others
# We want to maintain a respectful environment for everyone, which means you must
# follow these basic rules of conduct:
# comply with applicable laws, including export control, sanctions, money laundering,
# and human tracking laws
# respect the rights of others, including privacy and intellectual property rightsdon’t abuse or harm others or yourself (or threaten or encourage such abuse or
# harm) including against children — for example, by misleading, defrauding, illegally
# impersonating, defaming, bullying, harassing, or stalking others; hosting or
# publishing any obscene content; or inciting the violation of applicable laws
# Our service-specic additional terms and policies, such as our Generative AI Prohibited
# Use Policy, provide additional details about appropriate conduct that everyone using
# those services must follow.
#
# Generated Questions:
# - What are some basic rules of conduct?
# - What are some basic rules of conduct?
#
# --------------------------------------------------
#
# Passage 28:
# If you nd that others aren’t following these rules, many of
# our services allow you to report abuse.
#
# Generated Questions:
# - What do we do to help you report abuse?
# - What do we do to help you report abuse?
#
# --------------------------------------------------
#
# Passage 29:
# If we act on a report of abuse, we also provide the
# process described in the Taking action in case of problems section.
#
# Generated Questions:
# - What is the process described in the Taking action in case of problems section?
# - What is the process described in the Taking action in case of problems section?
#
# --------------------------------------------------
#
# Passage 30:
# Don’t abuse our services
# Most people who access or use our services understand the general rules that keep the
# internet safe and open.
#
# Generated Questions:
# - What are the rules of the internet?
# - What are the rules of the internet?
#
# --------------------------------------------------
#
# Passage 31:
# Unfortunately, a small number of people don’t respect those rules,
# so we’re describing them here to protect our services and users from abuse.
#
# Generated Questions:
# - What are the rules that we describe to protect our users from abuse?
# - What are the rules that we describe to protect our users from abuse?
#
# --------------------------------------------------
#
# Passage 32:
# In that spirit:
# You must not abuse, harm, interfere with, or disrupt our services or systems — for
# example, by:
# introducing malware
# spamming, hacking, or bypassing our systems or protective measures
# jailbreaking, adversarial prompting, or prompt injection, except as part of our safety
# and bug testing programs
# accessing or using our services or content in fraudulent or deceptive ways, such as:
# phishing
# creating fake accounts or content, including fake reviews
# misleading others into thinking that generative AI content was created by a
# human
# providing services that appear to originate from you (or someone else) when
# they actually originate from us
# providing services that appear to originate from us when they do not
# using our services (including the content they provide) to violate anyone’s legal
# rights, such as intellectual property or privacy rightsreverse engineering our services or underlying technology, such as our machine
# learning models, to extract trade secrets or other proprietary information, except as
# allowed by applicable law
# using automated means to access content from any of our services in violation of
# the machine-readable instructions on our web pages (for example, robots.txt les
# that disallow crawling, training, or other activities)
# using AI-generated content from our services to develop machine learning models or
# related AI technology
# hiding or misrepresenting who you are in order to violate these terms
# providing services that encourage others to violate these terms
# Permission to use your content
# Some of our services are designed to let you upload, submit, store, send, receive, or share
# your content.
#
# Generated Questions:
# - What is a violation of the terms of service?
# - What is a violation of the terms of service?
#
# --------------------------------------------------
#
# Passage 33:
# You have no obligation to provide any content to our services and you’re
# free to choose the content that you want to provide.
#
# Generated Questions:
# - What is the obligation to provide content to our services?
# - What is the obligation to provide content to our services?
#
# --------------------------------------------------
#
# Passage 34:
# If you choose to upload or share
# content, please make sure you have the necessary rights to do so and that the content is
# lawful.
#
# Generated Questions:
# - What do you need to know about the content you upload?
# - What do you need to know about the content you upload?
#
# --------------------------------------------------
#
# Passage 35:
# License
# Your content remains yours, which means that you retain any
# intellectual property rights that you have in your content.
#
# Generated Questions:
# - What is the term for the intellectual property rights in your content?
# - What is the term for the intellectual property rights in your content?
#
# --------------------------------------------------
#
# Passage 36:
# For
# example, you have intellectual property rights in the creative content
# you make, such as reviews you write.
#
# Generated Questions:
# - What intellectual property rights do you have in your content?
# - What intellectual property rights do you have in your content?
#
# --------------------------------------------------
#
# Passage 37:
# Or you may have the right to
# share someone else’s creative content if they’ve given you their
# permission.
#
# Generated Questions:
# - What is the right to share someone else's content?
# - What is the right to share someone else's content?
#
# --------------------------------------------------
#
# Passage 38:
# We need your permission if your intellectual property rights restrict
# our use of your content.
#
# Generated Questions:
# - What is the legal basis for limiting our use of your content?
# - What is the legal basis for limiting our use of your content?
#
# --------------------------------------------------
#
# Passage 39:
# You provide Google with that permission
# through this license.What’s covered
# This license covers your content if that content is protected by
# intellectual property rights.
#
# Generated Questions:
# - What is the scope of the license?
# - What is the scope of the license?
#
# --------------------------------------------------
#
# Passage 40:
# What’s not covered
# This license doesn’t affect your privacy rights — it’s only about
# your intellectual property rights
# This license doesn’t cover these types of content:
# publicly-available factual information that you provide,
# such as corrections to the address of a local business.
#
# Generated Questions:
# - What type of content is not covered by this license?
# - What type of content is not covered by this license?
#
# --------------------------------------------------
#
# Passage 41:
# That information doesn’t require a license because it’s
# considered common knowledge that everyone’s free to
# use.
#
# Generated Questions:
# - What is the common knowledge that everyone is free to use?
# - What is the common knowledge that everyone is free to use?
#
# --------------------------------------------------
#
# Passage 42:
# feedback that you offer, such as suggestions to
# improve our services.
#
# Generated Questions:
# - What do you offer to improve our services?
# - What do you offer to improve our services?
#
# --------------------------------------------------
#
# Passage 43:
# Feedback is covered in the
# Service-related communications section below.
#
# Generated Questions:
# - What is the purpose of the Service-related communications section below?
# - What is the purpose of the Service-related communications section below?
#
# --------------------------------------------------
#
# Passage 44:
# Scope
# This license is:
# worldwide, which means it’s valid anywhere in the world
# non-exclusive, which means you can license your content to
# others
# royalty-free, which means there are no monetary fees for this
# license
# Rights
# This license allows Google to:host, reproduce, distribute, communicate, and use your content
# — for example, to save your content on our systems and make
# it accessible from anywhere you go
# publish, publicly perform, or publicly display your content, if
# you’ve made it visible to others
# modify and create derivative works based on your content,
# such as reformatting or translating it
# sublicense these rights to:
# other users to allow the services to work as designed,
# such as enabling you to share photos with people you
# choose
# our contractors who’ve signed agreements with us that
# are consistent with these terms, only for the limited
# purposes described in the Purpose section below
# Purpose
# This license is for the limited purpose of:
# operating and improving the services, which means allowing
# the services to work as designed and creating new features
# and functionalities.
#
# Generated Questions:
# - What is the scope of the license?
# - What is the scope of the license?
#
# --------------------------------------------------
#
# Passage 45:
# This includes using automated systems
# and algorithms to analyze your content:
# for spam and malware
# to recognize patterns in data, such as determining
# when to suggest a new album in Google Photos to keep
# related photos together
# to customize our services for you, such as providing
# recommendations and personalized search results,
# content, and ads (which you can change or turn off in
# Ads Settings)
# This analysis occurs as the content is sent, received, and when
# it is stored.using content you’ve shared publicly to promote the services.
#
# Generated Questions:
# - What is the purpose of using automated systems and algorithms to analyze your content?
# - What is the purpose of using automated systems and algorithms to analyze your content?
#
# --------------------------------------------------
#
# Passage 46:
# For example, to promote a Google app, we might quote a
# review you wrote.
#
# Generated Questions:
# - What might be used to promote a Google app?
# - What might be used to promote a Google app?
#
# --------------------------------------------------
#
# Passage 47:
# Or to promote Google Play, we might show a
# screenshot of the app you offer in the Play Store.
#
# Generated Questions:
# - What might we show a screenshot of the app you offer in the Play Store?
# - What might we show a screenshot of the app you offer in the Play Store?
#
# --------------------------------------------------
#
# Passage 48:
# developing new technologies and services for Google
# consistent with these terms
# Duration
# This license lasts for as long as your content is protected by
# intellectual property rights.
#
# Generated Questions:
# - What is the term for Google's new technologies and services?
# - What is the term for Google's new technologies and services?
#
# --------------------------------------------------
#
# Passage 49:
# If you remove from our services any content that’s covered by this
# license, then our systems will stop making that content publicly
# available in a reasonable amount of time.
#
# Generated Questions:
# - What happens if you remove content from our services?
# - What happens if you remove content from our services?
#
# --------------------------------------------------
#
# Passage 50:
# There are two exceptions:
# If you already shared your content with others before removing
# it.
#
# Generated Questions:
# - What is the first exception to sharing content with others before removing it?
# - What is the first exception to sharing content with others before removing it?
#
# --------------------------------------------------
#
# Passage 51:
# For example, if you shared a photo with a friend who then
# made a copy of it, or shared it again, then that photo may
# continue to appear in your friend’s Google Account even after
# you remove it from your Google Account.
#
# Generated Questions:
# - What happens to a photo that appears in your friend's Google Account even after you remove it
# - What happens to a photo that appears in your friend's Google Account even after you remove it
#
# --------------------------------------------------
#
# Passage 52:
# If you make your content available through other companies’
# services, it’s possible that search engines, including Google
# Search, will continue to nd and display your content as part of
# their search results.
#
# Generated Questions:
# - What is the likelihood that search engines will display your content as part of their search results?
# - What is the likelihood that search engines will display your content as part of their search results?
#
# --------------------------------------------------
#
# Passage 53:
# Using Google servicesYour Google Account
# If you meet these age requirements you can create a Google Account for your
# convenience.
#
# Generated Questions:
# - What age requirements do you need to create a Google account for?
# - What age requirements do you need to create a Google account for?
#
# --------------------------------------------------
#
# Passage 54:
# Some services require that you have a Google Account in order to work —
# for example, to use Gmail, you need a Google Account so that you have a place to send
# and receive your email.
#
# Generated Questions:
# - What does a Google account require to use Gmail?
# - What does a Google account require to use Gmail?
#
# --------------------------------------------------
#
# Passage 55:
# You’re responsible for what you do with your Google Account, including taking
# reasonable steps to keep your Google Account secure, and we encourage you to regularly
# use the Security Checkup.
#
# Generated Questions:
# - What is the responsibility of keeping your Google Account secure?
# - What is the responsibility of keeping your Google Account secure?
#
# --------------------------------------------------
#
# Passage 56:
# Using Google services on behalf of an organization or
# business
# Many organizations, such as businesses, non-prots, and schools, take advantage of our
# services.
#
# Generated Questions:
# - What is the purpose of using Google services for an organization?
# - What is the purpose of using Google services for an organization?
#
# --------------------------------------------------
#
# Passage 57:
# To use our services on behalf of an organization:
# an authorized representative of that organization must agree to these terms
# your organization’s administrator may assign a Google Account to you.
#
# Generated Questions:
# - What is the name of the person who can use Google services on behalf of an organization?
# - What is the name of the person who can use Google services on behalf of an organization?
#
# --------------------------------------------------
#
# Passage 58:
# That
# administrator might require you to follow additional rules and may be able to access
# or disable your Google Account.
#
# Generated Questions:
# - What may be required of you to follow additional rules?
# - What may be required of you to follow additional rules?
#
# --------------------------------------------------
#
# Passage 59:
# Service-related communications
# To provide you with our services, we sometimes send you service announcements and
# other information.
#
# Generated Questions:
# - What do we send to you to provide you with our services?
# - What do we send to you to provide you with our services?
#
# --------------------------------------------------
#
# Passage 60:
# To learn more about how we communicate with you, see Google’s
# Privacy Policy.
#
# Generated Questions:
# - What does Google do with you?
# - What does Google do with you?
#
# --------------------------------------------------
#
# Passage 61:
# If you choose to give us feedback, such as suggestions to improve our services, we may
# act on your feedback without obligation to you.Content in Google services
# Your content
# Some of our services allow you to generate original content.
#
# Generated Questions:
# - What is the purpose of your feedback?
# - What is the purpose of your feedback?
#
# --------------------------------------------------
#
# Passage 62:
# Google won’t claim
# ownership over that content.
#
# Generated Questions:
# - What content does Google not own?
# - What content does Google not own?
#
# --------------------------------------------------
#
# Passage 63:
# Some of our services give you the opportunity to make your content publicly available —
# for example, you might post a product or restaurant review that you wrote, or you might
# upload a blog post that you created.
#
# Generated Questions:
# - What kind of content can you make public?
# - What kind of content can you make public?
#
# --------------------------------------------------
#
# Passage 64:
# See the Permission to use your content section for more about your rights in your
# content, and how your content is used in our services
# See the Removing your content section to learn why and how we might remove user-
# generated content from our services
# If you think someone is infringing your intellectual property rights, you can send us notice
# of the infringement and we’ll take appropriate action.
#
# Generated Questions:
# - What is the Permission to use your content section of our services?
# - What is the Permission to use your content section of our services?
#
# --------------------------------------------------
#
# Passage 65:
# For example, we suspend or close
# the Google Accounts of repeat copyright infringers as described in our Copyright Help
# Center.
#
# Generated Questions:
# - What does Google do to prevent repeat copyright infringers?
# - What does Google do to prevent repeat copyright infringers?
#
# --------------------------------------------------
#
# Passage 66:
# Google content
# Some of our services include content that belongs to Google — for example, many of the
# visual illustrations you see in Google Maps.
#
# Generated Questions:
# - What is the name of the content that Google provides?
# - What is the name of the content that Google provides?
#
# --------------------------------------------------
#
# Passage 67:
# You may use Google’s content as allowed by
# these terms and any service-specic additional terms, but we retain any intellectual
# property rights that we have in our content.
#
# Generated Questions:
# - What is the name of the company that owns the intellectual property rights in its content?
# - What is the name of the company that owns the intellectual property rights in its content?
#
# --------------------------------------------------
#
# Passage 68:
# Don’t remove, obscure, or alter any of our
# branding, logos, or legal notices.
#
# Generated Questions:
# - What do you do not do with our branding?
# - What do you do not do with our branding?
#
# --------------------------------------------------
#
# Passage 69:
# If you want to use our branding or logos, please see the
# Google Brand Permissions page.Other content
# Finally, some of our services give you access to content that belongs to other people or
# organizations — for example, a store owner’s description of their own business, or a
# newspaper article displayed in Google News.
#
# Generated Questions:
# - What is the name of the page that Google allows you to use?
# - What is the name of the page that Google allows you to use?
#
# --------------------------------------------------
#
# Passage 70:
# You may not use this content without that
# person or organization’s permission, or as otherwise allowed by law.
#
# Generated Questions:
# - What is the legal basis for using this content?
# - What is the legal basis for using this content?
#
# --------------------------------------------------
#
# Passage 71:
# The views expressed
# in other people or organizations’ content are theirs, and don’t necessarily reect Google’s
# views.
#
# Generated Questions:
# - What is the name of the company that publishes content that is not Google's?
# - What is the name of the company that publishes content that is not Google's?
#
# --------------------------------------------------
#
# Passage 72:
# Soware in Google services
# Some of our services include downloadable or preloaded software.
#
# Generated Questions:
# - What is the name of the service that Google provides?
# - What is the name of the service that Google provides?
#
# --------------------------------------------------
#
# Passage 73:
# We give you
# permission to use that software as part of the services.
#
# Generated Questions:
# - What does the software do with the permission of the service provider?
# - What does the software do with the permission of the service provider?
#
# --------------------------------------------------
#
# Passage 74:
# The license we give you is:
# worldwide, which means it’s valid anywhere in the world
# non-exclusive, which means that we can license the software to others
# royalty-free, which means there are no monetary fees for this license
# personal, which means it doesn’t extend to anyone else
# non-assignable, which means you’re not allowed to assign the license to anyone else
# Some of our services include software that’s offered under open source license terms that
# we make available to you.
#
# Generated Questions:
# - What is the license we give you?
# - What is the license we give you?
#
# --------------------------------------------------
#
# Passage 75:
# Sometimes there are provisions in the open source license that
# explicitly override parts of these terms, so please be sure to read those licenses.You may not copy, modify, distribute, sell, or lease any part of our services or software.
#
# Generated Questions:
# - What is the name of the software that you may not use?
# - What is the name of the software that you may not use?
#
# --------------------------------------------------
#
# Passage 76:
# In case of problems or disagreements
# Both the law and these terms give you the right to (1) a certain quality of service, and (2)
# ways to x problems if things go wrong.
#
# Generated Questions:
# - What does the law give you?
# - What does the law give you?
#
# --------------------------------------------------
#
# Passage 77:
# Warranty
# We provide our services using reasonable skill and care.
#
# Generated Questions:
# - What is the warranty on our services?
# - What is the warranty on our services?
#
# --------------------------------------------------
#
# Passage 78:
# If we don’t meet the quality level
# described in this warranty, you agree to tell us and we’ll work with you to try to resolve the
# issue.
#
# Generated Questions:
# - What is the warranty term for?
# - What is the warranty term for?
#
# --------------------------------------------------
#
# Passage 79:
# Disclaimers
# The only commitments we make about our services (including the content in the services,
# the specic functions of our services, or their reliability, availability, or ability to meet your
# needs) are provided in (1) the Warranty section; (2) the service-specic additional terms;
# and (3) laws that can’t be limited by these terms.
#
# Generated Questions:
# - What is the warranty section of our services?
# - What is the warranty section of our services?
#
# --------------------------------------------------
#
# Passage 80:
# Don’t rely on the services for medical, legal, nancial, or other professional advice.
#
# Generated Questions:
# - What is the main reason you should not rely on the services of a doctor?
# - What is the main reason you should not rely on the services of a doctor?
#
# --------------------------------------------------
#
# Passage 81:
# Any
# content regarding those topics is provided for informational purposes only and is not a
# substitute for advice from a qualied professional.
#
# Generated Questions:
# - What is the purpose of the content?
# - What is the purpose of the content?
#
# --------------------------------------------------
#
# Passage 82:
# Liabilities
# For all usersBoth the law and these terms try to strike a balance as to what you or Google can claim
# from the other in case of problems.
#
# Generated Questions:
# - What is the law of Google?
# - What is the law of Google?
#
# --------------------------------------------------
#
# Passage 83:
# That’s why the law requires everyone to be
# responsible for certain liabilities — but not others — under these terms.
#
# Generated Questions:
# - What is the law that requires everyone to be responsible for certain liabilities?
# - What is the law that requires everyone to be responsible for certain liabilities?
#
# --------------------------------------------------
#
# Passage 84:
# These terms only limit our responsibilities as allowed by applicable law.
#
# Generated Questions:
# - What are the terms of this agreement?
# - What are the terms of this agreement?
#
# --------------------------------------------------
#
# Passage 85:
# These terms don’t
# limit liability for:
# fraud or fraudulent misrepresentation
# death or personal injury caused by negligence
# gross negligence
# willful misconduct
# Other than the liabilities described above, Google is liable only for its breaches of these
# terms or applicable service-specic additional terms, subject to applicable law.
#
# Generated Questions:
# - What is the liability of Google for breach of these terms?
# - What is the liability of Google for breach of these terms?
#
# --------------------------------------------------
#
# Passage 86:
# For business users and organizations only
# If you’re a business user or organization:
# To the extent allowed by applicable law, you’ll indemnify Google and its directors,
# ocers, employees, and contractors for any third-party legal proceedings (including
# actions by government authorities) arising out of or relating to your unlawful use of
# the services or violation of these terms or service-specic additional terms.
#
# Generated Questions:
# - What is the legal term for Google's liability to you?
# - What is the legal term for Google's liability to you?
#
# --------------------------------------------------
#
# Passage 87:
# This
# indemnity covers any liability or expense arising from claims, losses, damages,
# judgments, nes, litigation costs, and legal fees, except to the extent a liability or
# expense is caused by Google's breach, negligence, or willful misconduct.
#
# Generated Questions:
# - What is the liability of Google for damages?
# - What is the liability of Google for damages?
#
# --------------------------------------------------
#
# Passage 88:
# If you’re legally exempt from certain responsibilities, including indemnication, then
# those responsibilities don’t apply to you under these terms.
#
# Generated Questions:
# - What are the responsibilities that don't apply to you under these terms?
# - What are the responsibilities that don't apply to you under these terms?
#
# --------------------------------------------------
#
# Passage 89:
# For example, the United
# Nations enjoys certain immunities from legal obligations and these terms don’t
# override those immunities.
#
# Generated Questions:
# - What does the United Nations enjoy immunities from legal obligations?
# - What does the United Nations enjoy immunities from legal obligations?
#
# --------------------------------------------------
#
# Passage 90:
# Google won’t be responsible for the following liabilities:
# loss of prots, revenues, business opportunities, goodwill, or anticipated
# savings
# indirect or consequential lossExcept as stated in the For all users section above, Google’s total liability arising out
# of or relating to these terms is limited to the greater of (1) US$500 or (2) 125% of the
# fees that you paid to use the relevant services in the 12 months before the breach.
#
# Generated Questions:
# - What is the maximum amount of liability that Google can assume for the breach of these terms?
# - What is the maximum amount of liability that Google can assume for the breach of these terms?
#
# --------------------------------------------------
#
# Passage 91:
# Taking action in case of problems
# Before taking action as described below, we’ll provide you with advance notice when
# reasonably possible, describe the reason for our action, and give you an opportunity to
# clarify the issue and address it, unless we reasonably believe that doing so would:
# cause harm or liability to a user, third party, or Google
# violate the law or a legal enforcement authority’s order
# compromise an investigation
# compromise the operation, integrity, or security of our services
# Removing your content
# If we reasonably believe that any of your content (1) breaches these terms, service-
# specic additional terms or policies, (2) violates applicable law, or (3) could harm our
# users, third parties, or Google, then we reserve the right to take down some or all of that
# content in accordance with applicable law.
#
# Generated Questions:
# - What is the reason for taking action?
# - What is the reason for taking action?
#
# --------------------------------------------------
#
# Passage 92:
# Examples include child pornography, content
# that facilitates human tracking or harassment, terrorist content, and content that
# infringes someone else’s intellectual property rights.
#
# Generated Questions:
# - What is a common type of content that infringes on someone else's intellectual
# - What is a common type of content that infringes on someone else's intellectual
#
# --------------------------------------------------
#
# Passage 93:
# Suspending or terminating your access to Google services
# Without limiting any of our other rights, Google may suspend or terminate your access to
# the services or delete your Google Account if any of these things happen:
# you materially or repeatedly breach these terms, service-specic additional terms or
# policies
# we’re required to do so to comply with a legal requirement or a court order
# we reasonably believe that your conduct causes harm or liability to a user, third
# party, or Google — for example, by hacking, phishing, harassing, spamming,misleading others, or scraping content that doesn’t belong to you
# For more information about why we disable accounts and what happens when we do,
# see this Help Center page.
#
# Generated Questions:
# - What is the reason Google may suspend or terminate your access to the services?
# - What is the reason Google may suspend or terminate your access to the services?
#
# --------------------------------------------------
#
# Passage 94:
# If you believe your Google Account has been suspended or
# terminated in error, you can appeal.
#
# Generated Questions:
# - What is the reason you can appeal your Google Account suspension?
# - What is the reason you can appeal your Google Account suspension?
#
# --------------------------------------------------
#
# Passage 95:
# Of course, you’re always free to stop using our services at any time.
#
# Generated Questions:
# - What is the free option to stop using our services?
# - What is the free option to stop using our services?
#
# --------------------------------------------------
#
# Passage 96:
# If you do stop using a
# service, we’d appreciate knowing why so that we can continue improving our services.
#
# Generated Questions:
# - What would you do if you stopped using a service?
# - What would you do if you stopped using a service?
#
# --------------------------------------------------
#
# Passage 97:
# Seling disputes, governing law, and courts
# For information about how to contact Google, please visit our contact page.
#
# Generated Questions:
# - What is the name of the company that Google is a part of?
# - What is the name of the company that Google is a part of?
#
# --------------------------------------------------
#
# Passage 98:
# California law will govern all disputes arising out of or relating to these terms, service-
# specic additional terms, or any related services, regardless of conict of laws rules.
#
# Generated Questions:
# - What is the legal basis for all disputes arising out of these terms?
# - What is the legal basis for all disputes arising out of these terms?
#
# --------------------------------------------------
#
# Passage 99:
# These disputes will be resolved exclusively in the federal or state courts of Santa Clara
# County, California, USA, and you and Google consent to personal jurisdiction in those
# courts.
#
# Generated Questions:
# - What is the name of the state court where Google and you are legally bound to be?
# - What is the name of the state court where Google and you are legally bound to be?
#
# --------------------------------------------------
#
# Passage 100:
# To the extent that applicable local law prevents certain disputes from being resolved in a
# California court, then you can le those disputes in your local courts.
#
# Generated Questions:
# - What is the legal basis for a California court case?
# - What is the legal basis for a California court case?
#
# --------------------------------------------------
#
# Passage 101:
# Likewise, if
# applicable local law prevents your local court from applying California law to resolve
# these disputes, then these disputes will be governed by the applicable local laws of your
# country, state, or other place of residence.
#
# Generated Questions:
# - What local law will govern disputes if California law is not applied?
# - What local law will govern disputes if California law is not applied?
#
# --------------------------------------------------
#
# Passage 102:
# About these terms
# By law, you have certain rights that can’t be limited by a contract like these terms of
# service.
#
# Generated Questions:
# - What is the meaning of the terms of service?
# - What is the meaning of the terms of service?
#
# --------------------------------------------------
#
# Passage 103:
# These terms are in no way intended to restrict those rights.
#
# Generated Questions:
# - What are the terms of these terms not intended to restrict?
# - What are the terms of these terms not intended to restrict?
#
# --------------------------------------------------
#
# Passage 104:
# These terms describe the relationship between you and Google.
#
# Generated Questions:
# - What terms describe the relationship between you and Google?
# - What terms describe the relationship between you and Google?
#
# --------------------------------------------------
#
# Passage 105:
# They don’t create any
# legal rights for other people or organizations, even if others benet from that relationshipunder these terms.
#
# Generated Questions:
# - What are the terms of a relationship?
# - What are the terms of a relationship?
#
# --------------------------------------------------
#
# Passage 106:
# We want to make these terms easy to understand, so we’ve used examples from our
# services.
#
# Generated Questions:
# - What are some examples from our services?
# - What are some examples from our services?
#
# --------------------------------------------------
#
# Passage 107:
# But not all services mentioned may be available in your country.
#
# Generated Questions:
# - What services may not be available in your country?
# - What services may not be available in your country?
#
# --------------------------------------------------
#
# Passage 108:
# If these terms conict with the service-specic additional terms, the additional terms will
# govern for that service.
#
# Generated Questions:
# - What will govern for the service if the terms are conict with the service-spec
# - What will govern for the service if the terms are conict with the service-spec
#
# --------------------------------------------------
#
# Passage 109:
# If it turns out that a particular term is not valid or enforceable, this will not affect any
# other terms.
#
# Generated Questions:
# - What happens if a term is not valid or enforceable?
# - What happens if a term is not valid or enforceable?
#
# --------------------------------------------------
#
# Passage 110:
# If you don’t follow these terms or the service-specic additional terms, and we don’t take
# action right away, that doesn’t mean we’re giving up any rights that we may have, such as
# taking action in the future.
#
# Generated Questions:
# - What is the term for the additional terms?
# - What is the term for the additional terms?
#
# --------------------------------------------------
#
# Passage 111:
# We may update these terms and service-specic additional terms (1) to reect changes in
# our services or how we do business — for example, when we add new services, features,
# technologies, pricing, or benets (or remove old ones), (2) for legal, regulatory, or security
# reasons, or (3) to prevent abuse or harm.
#
# Generated Questions:
# - What may we update these terms and service-specic additional terms to reflect changes in our
# - What may we update these terms and service-specic additional terms to reflect changes in our
#
# --------------------------------------------------
#
# Passage 112:
# If we materially change these terms or service-specic additional terms, we’ll provide you
# with reasonable advance notice and the opportunity to review the changes, except (1)
# when we launch a new service or feature, or (2) in urgent situations, such as preventing
# ongoing abuse or responding to legal requirements.
#
# Generated Questions:
# - What is the reason for the change?
# - What is the reason for the change?
#
# --------------------------------------------------
#
# Passage 113:
# If you don’t agree to the new terms,
# you should remove your content and stop using the services.
#
# Generated Questions:
# - What should you do if you don't agree to the new terms?
# - What should you do if you don't agree to the new terms?
#
# --------------------------------------------------
#
# Passage 114:
# You can also end your
# relationship with us at any time by closing your Google Account.
#
# Generated Questions:
# - What is the name of the service that you can end your relationship with us?
# - What is the name of the service that you can end your relationship with us?
#
# --------------------------------------------------
#
# Passage 115:
# DEFINITIONS
# aliate
# An entity that belongs to the Google group of companies, which means Google LLC and
# its subsidiaries, including the following companies that provide consumer services in the
# EU: Google Ireland Limited, Google Commerce Limited, and Google Dialer Inc.business user
# An individual or entity who is not a consumer (see consumer).
#
# Generated Questions:
# - What does aliate mean?
# - What does aliate mean?
#
# --------------------------------------------------
#
# Passage 116:
# consumer
# An individual who uses Google services for personal, non-commercial purposes outside of
# their trade, business, craft, or profession.
#
# Generated Questions:
# - What is the definition of a consumer?
# - What is the definition of a consumer?
#
# --------------------------------------------------
#
# Passage 117:
# (See business user)
# copyright
# A legal right that allows the creator of an original work (such as a blog post, photo, or
# video) to decide if and how that original work may be used by others, subject to certain
# limitations and exceptions (such as “fair use” and “fair dealing”).
#
# Generated Questions:
# - What is the definition of copyright?
# - What is the definition of copyright?
#
# --------------------------------------------------
#
# Passage 118:
# disclaimer
# A statement that limits someone’s legal responsibilities.
#
# Generated Questions:
# - What is a disclaimer?
# - What is a disclaimer?
#
# --------------------------------------------------
#
# Passage 119:
# indemnify or indemnity
# An individual or organization’s contractual obligation to compensate the losses suffered
# by another individual or organization from legal proceedings such as lawsuits.
#
# Generated Questions:
# - What is an example of an obligation to indemnify an individual or organization?
# - What is an example of an obligation to indemnify an individual or organization?
#
# --------------------------------------------------
#
# Passage 120:
# intellectual property rights (IP rights)
# Rights over the creations of a person’s mind, such as inventions (patent rights); literary
# and artistic works (copyright); designs (design rights); and symbols, names, and images
# used in commerce (trademarks).
#
# Generated Questions:
# - What is the definition of IP rights?
# - What is the definition of IP rights?
#
# --------------------------------------------------
#
# Passage 121:
# IP rights may belong to you, another individual, or an
# organization.
#
# Generated Questions:
# - What is the legal definition of IP rights?
# - What is the legal definition of IP rights?
#
# --------------------------------------------------
#
# Passage 122:
# liabilityLosses from any type of legal claim, whether the claim is based on a contract, tort
# (including negligence), or other reason, and whether or not those losses could have been
# reasonably anticipated or foreseen.
#
# Generated Questions:
# - What is the reason for a claim?
# - What is the reason for a claim?
#
# --------------------------------------------------
#
# Passage 123:
# organization
# A legal entity (such as a corporation, non-prot, or school) and not an individual person.
#
# Generated Questions:
# - What is a legal entity?
# - What is a legal entity?
#
# --------------------------------------------------
#
# Passage 124:
# services
# The Google services that are subject to these terms are the products and services listed at
# https://policies.google.com/terms/service-specic, including:
# apps and sites (like Search and Maps)
# platforms (like Google Shopping)
# integrated services (like Maps embedded in other companies’ apps or sites)
# devices and other goods (like Google Nest)
# Many of these services also include content that you can stream or interact with.
#
# Generated Questions:
# - What are the terms for services that are subject to these terms?
# - What are the terms for services that are subject to these terms?
#
# --------------------------------------------------
#
# Passage 125:
# trademark
# Symbols, names, and images used in commerce that are capable of distinguishing the
# goods or services of one individual or organization from those of another.
#
# Generated Questions:
# - What is a trademark?
# - What is a trademark?
#
# --------------------------------------------------
#
# Passage 126:
# warranty
# An assurance that a product or service will perform to a certain standard.
#
# Generated Questions:
# - What is a warranty?
# - What is a warranty?
#
# --------------------------------------------------
#
# Passage 127:
# your contentThings that you create, upload, submit, store, send, receive, or share using our services,
# such as:
# Docs, Sheets, and Slides you create
# blog posts you upload through Blogger
# reviews you submit through Maps
# videos you store in Drive
# emails you send and receive through Gmail
# pictures you share with friends through Photos
# travel itineraries that you share with Google
#
# Generated Questions:
# - What are some of the services that you use?
# - What are some of the services that you use?
#
# --------------------------------------------------

# %%
# load the QA pipeline
qa_pipeline = pipeline("question-answering", model="deepset/roberta-base-squad2")

# function to track and answer only unique questions
def answer_unique_questions(passages, qa_pipeline):
    answered_questions = set()  # to store unique questions

    for idx, passage in enumerate(passages):
        questions = generate_questions_pipeline(passage)

        for question in questions:
            if question not in answered_questions:  # check if the question has already been answered
                answer = qa_pipeline({'question': question, 'context': passage})
                print(f"Q: {question}")
                print(f"A: {answer['answer']}\n")
                answered_questions.add(question)  # add the question to the set to avoid repetition
        print(f"{'='*50}\n")

answer_unique_questions(passages, qa_pipeline)
# Out:
# Device set to use cpu
# Q: What is the term for the Google Terms of Service?
# A: Terms of
# Service
#
# ==================================================
#
# Q: What are the Terms of Service?
# A: reect the way Google’s business works
#
# ==================================================
#
# ==================================================
#
# Q: What does the term "What you can expect from us" mean?
# A: how we provide and develop our
# services
#
# ==================================================
#
# Q: What is the Privacy Policy?
# A: terms
#
# ==================================================
#
# Q: What is the name of the company that provides Google services?
# A: Google LLC
#
# ==================================================
#
# Q: What do you need to do to read the terms?
# A: your
# parent or legal guardian
#
# ==================================================
#
# Q: What are the terms of service for parents and guardians?
# A:
# these terms apply to you
#
# ==================================================
#
# Q: What is the age requirement for some services?
# A: service-
# specic additional terms and policies
#
# ==================================================
#
# Q: What terms help delineate the relationship between you and Google?
# A: GoogleThese terms help de
#
# ==================================================
#
# Q: What does Google mean by Google LLC?
# A: aliates
#
# ==================================================
#
# Q: What are the terms of Google's business?
# A: how Google’s business works
# and how we earn money
#
# ==================================================
#
# Q: What kind of services do you expect from Google?
# A: Provide a broad range of useful services
#
# ==================================================
#
# Q: What is the purpose of our services?
# A: to work together
#
# ==================================================
#
# Q: What can Maps show you how to get to an address?
# A: click
# on that address
#
# ==================================================
#
# Q: What is the purpose of the Google services?
# A: improve
#
# ==================================================
#
# Q: What do we use to provide you with simultaneous translations?
# A: articial intelligence and machine learning
#
# ==================================================
#
# Q: What does it mean to add or remove features and functionalities?
# A: continual improvement
#
# ==================================================
#
# Q: What happens when a service requires or includes downloadable or preloaded software?
# A: updates automatically on your device
#
# ==================================================
#
# Q: What is the name of the service that lets you adjust your automatic update settings?
# A: services
#
# ==================================================
#
# Q: What is the legal requirement for Google Takeout?
# A: subject to applicable law and
# policies
#
# ==================================================
#
# Q: What are the terms that we expect from you?
# A: Follow these terms and service-specic additional terms
#
# ==================================================
#
# Q: What resources are available from our policies site?
# A: Privacy Policy, Copyright Help Center, Safety Center, Transparency
# Center
#
# ==================================================
#
# Q: What do we provide to you in our services?
# A: specic
# instructions and warnings
#
# ==================================================
#
# Q: What does the term "intellectual property" mean?
# A: rights
#
# ==================================================
#
# Q: What are some basic rules of conduct?
# A: comply with applicable laws
#
# ==================================================
#
# Q: What do we do to help you report abuse?
# A: If you nd that others aren’t following these rules
#
# ==================================================
#
# Q: What is the process described in the Taking action in case of problems section?
# A: If we act on a report of abuse
#
# ==================================================
#
# Q: What are the rules of the internet?
# A: safe and open
#
# ==================================================
#
# Q: What are the rules that we describe to protect our users from abuse?
# A: a small number of people don’t respect those rules
#
# ==================================================
#
# Q: What is a violation of the terms of service?
# A:
# phishing
#
# ==================================================
#
# Q: What is the obligation to provide content to our services?
# A: no
#
# ==================================================
#
# Q: What do you need to know about the content you upload?
# A: the content is
# lawful
#
# ==================================================
#
# Q: What is the term for the intellectual property rights in your content?
# A: License
#
# ==================================================
#
# Q: What intellectual property rights do you have in your content?
# A: reviews you write
#
# ==================================================
#
# Q: What is the right to share someone else's content?
# A: if they’ve given you their
# permission
#
# ==================================================
#
# Q: What is the legal basis for limiting our use of your content?
# A: intellectual property rights
#
# ==================================================
#
# Q: What is the scope of the license?
# A: your content if that content is protected by
# intellectual property rights
#
# ==================================================
#
# Q: What type of content is not covered by this license?
# A: publicly-available factual information that you provide
#
# ==================================================
#
# Q: What is the common knowledge that everyone is free to use?
# A: information
#
# ==================================================
#
# Q: What do you offer to improve our services?
# A: suggestions
#
# ==================================================
#
# Q: What is the purpose of the Service-related communications section below?
# A: Feedback
#
# ==================================================
#
# ==================================================
#
# Q: What is the purpose of using automated systems and algorithms to analyze your content?
# A: to recognize patterns in data
#
# ==================================================
#
# Q: What might be used to promote a Google app?
# A: a
# review
#
# ==================================================
#
# Q: What might we show a screenshot of the app you offer in the Play Store?
# A: to promote Google Play
#
# ==================================================
#
# Q: What is the term for Google's new technologies and services?
# A:
# Duration
#
# ==================================================
#
# Q: What happens if you remove content from our services?
# A: our systems will stop making that content publicly
# available
#
# ==================================================
#
# Q: What is the first exception to sharing content with others before removing it?
# A: If you already shared your content with others before removing
# it
#
# ==================================================
#
# Q: What happens to a photo that appears in your friend's Google Account even after you remove it
# A: continue
#
# ==================================================
#
# Q: What is the likelihood that search engines will display your content as part of their search results?
# A: If you make your content available through other companies’
# services
#
# ==================================================
#
# Q: What age requirements do you need to create a Google account for?
# A: your
# convenience
#
# ==================================================
#
# Q: What does a Google account require to use Gmail?
# A: so that you have a place to send
# and receive your email
#
# ==================================================
#
# Q: What is the responsibility of keeping your Google Account secure?
# A: taking
# reasonable steps
#
# ==================================================
#
# Q: What is the purpose of using Google services for an organization?
# A: on behalf of an organization or
# business
#
# ==================================================
#
# Q: What is the name of the person who can use Google services on behalf of an organization?
# A: administrator
#
# ==================================================
#
# Q: What may be required of you to follow additional rules?
# A:
# administrator
#
# ==================================================
#
# Q: What do we send to you to provide you with our services?
# A: service announcements and
# other information
#
# ==================================================
#
# Q: What does Google do with you?
# A: communicate with you, see Google’s
# Privacy Policy
#
# ==================================================
#
# Q: What is the purpose of your feedback?
# A: suggestions to improve our services
#
# ==================================================
#
# Q: What content does Google not own?
# A:
# ownership
#
# ==================================================
#
# Q: What kind of content can you make public?
# A: product or restaurant review
#
# ==================================================
#
# Q: What is the Permission to use your content section of our services?
# A: how your content is used in our services
#
# ==================================================
#
# Q: What does Google do to prevent repeat copyright infringers?
# A: we suspend or close
# the Google Accounts
#
# ==================================================
#
# Q: What is the name of the content that Google provides?
# A:
# visual illustrations
#
# ==================================================
#
# Q: What is the name of the company that owns the intellectual property rights in its content?
# A: Google
#
# ==================================================
#
# Q: What do you do not do with our branding?
# A: remove, obscure, or alter
#
# ==================================================
#
# Q: What is the name of the page that Google allows you to use?
# A:
# Google Brand Permissions page
#
# ==================================================
#
# Q: What is the legal basis for using this content?
# A: allowed by law
#
# ==================================================
#
# Q: What is the name of the company that publishes content that is not Google's?
# A: theirs
#
# ==================================================
#
# Q: What is the name of the service that Google provides?
# A: downloadable or preloaded software
#
# ==================================================
#
# Q: What does the software do with the permission of the service provider?
# A: use that software as part of the services
#
# ==================================================
#
# Q: What is the license we give you?
# A:
# worldwide
#
# ==================================================
#
# Q: What is the name of the software that you may not use?
# A: our services or software
#
# ==================================================
#
# Q: What does the law give you?
# A: the right to (1) a certain quality of service
#
# ==================================================
#
# Q: What is the warranty on our services?
# A: We provide our services using reasonable skill and care
#
# ==================================================
#
# Q: What is the warranty term for?
# A: quality level
#
# ==================================================
#
# Q: What is the warranty section of our services?
# A: (1
#
# ==================================================
#
# Q: What is the main reason you should not rely on the services of a doctor?
# A: professional advice
#
# ==================================================
#
# Q: What is the purpose of the content?
# A: informational
#
# ==================================================
#
# Q: What is the law of Google?
# A: you or Google can claim
# from the other in case of problems
#
# ==================================================
#
# Q: What is the law that requires everyone to be responsible for certain liabilities?
# A: under these terms
#
# ==================================================
#
# Q: What are the terms of this agreement?
# A: only limit our responsibilities as allowed by applicable law
#
# ==================================================
#
# Q: What is the liability of Google for breach of these terms?
# A: Google is liable only
#
# ==================================================
#
# Q: What is the legal term for Google's liability to you?
# A: indemnify
#
# ==================================================
#
# Q: What is the liability of Google for damages?
# A:
# indemnity covers any liability or expense
#
# ==================================================
#
# Q: What are the responsibilities that don't apply to you under these terms?
# A: indemnication
#
# ==================================================
#
# Q: What does the United Nations enjoy immunities from legal obligations?
# A: these terms don’t
# override those immunities
#
# ==================================================
#
# Q: What is the maximum amount of liability that Google can assume for the breach of these terms?
# A: US$500
#
# ==================================================
#
# Q: What is the reason for taking action?
# A: describe the reason for our action
#
# ==================================================
#
# Q: What is a common type of content that infringes on someone else's intellectual
# A: terrorist content
#
# ==================================================
#
# Q: What is the reason Google may suspend or terminate your access to the services?
# A: if any of these things happen
#
# ==================================================
#
# Q: What is the reason you can appeal your Google Account suspension?
# A: If you believe your Google Account has been suspended or
# terminated in error
#
# ==================================================
#
# Q: What is the free option to stop using our services?
# A: you’re always free to stop using our services at any time
#
# ==================================================
#
# Q: What would you do if you stopped using a service?
# A: we’d appreciate knowing why so that we can continue improving our services
#
# ==================================================
#
# Q: What is the name of the company that Google is a part of?
# A:
#
# ==================================================
#
# Q: What is the legal basis for all disputes arising out of these terms?
# A: California law
#
# ==================================================
#
# Q: What is the name of the state court where Google and you are legally bound to be?
# A: Santa Clara
# County
#
# ==================================================
#
# Q: What is the legal basis for a California court case?
# A: local law
#
# ==================================================
#
# Q: What local law will govern disputes if California law is not applied?
# A: applicable local laws of your
# country, state, or other place of residence
#
# ==================================================
#
# Q: What is the meaning of the terms of service?
# A: you have certain rights
#
# ==================================================
#
# Q: What are the terms of these terms not intended to restrict?
# A: rights
#
# ==================================================
#
# Q: What terms describe the relationship between you and Google?
# A: These terms describe the relationship between you and Google.
#
# ==================================================
#
# Q: What are the terms of a relationship?
# A: They don’t create any
# legal rights for other people or organizations
#
# ==================================================
#
# Q: What are some examples from our services?
# A:
# services
#
# ==================================================
#
# Q: What services may not be available in your country?
# A: all services
#
# ==================================================
#
# Q: What will govern for the service if the terms are conict with the service-spec
# A: the additional terms
#
# ==================================================
#
# Q: What happens if a term is not valid or enforceable?
# A: this will not affect any
# other terms
#
# ==================================================
#
# Q: What is the term for the additional terms?
# A: service-specic
#
# ==================================================
#
# Q: What may we update these terms and service-specic additional terms to reflect changes in our
# A: our services or how we do business
#
# ==================================================
#
# Q: What is the reason for the change?
# A: preventing
# ongoing abuse or responding to legal requirements
#
# ==================================================
#
# Q: What should you do if you don't agree to the new terms?
# A: remove your content and stop using the services
#
# ==================================================
#
# Q: What is the name of the service that you can end your relationship with us?
# A: Google Account
#
# ==================================================
#
# Q: What does aliate mean?
# A: An entity that belongs to the Google group of companies
#
# ==================================================
#
# Q: What is the definition of a consumer?
# A: An individual who uses Google services
#
# ==================================================
#
# Q: What is the definition of copyright?
# A: A legal right that allows the creator of an original work
#
# ==================================================
#
# Q: What is a disclaimer?
# A: A statement that limits someone’s legal responsibilities
#
# ==================================================
#
# Q: What is an example of an obligation to indemnify an individual or organization?
# A: lawsuits
#
# ==================================================
#
# Q: What is the definition of IP rights?
# A: intellectual property rights
#
# ==================================================
#
# Q: What is the legal definition of IP rights?
# A: may belong to you, another individual, or an
# organization
#
# ==================================================
#
# Q: What is the reason for a claim?
# A: a contract
#
# ==================================================
#
# Q: What is a legal entity?
# A: a corporation
#
# ==================================================
#
# Q: What are the terms for services that are subject to these terms?
# A: apps and sites
#
# ==================================================
#
# Q: What is a trademark?
# A: Symbols, names, and images
#
# ==================================================
#
# Q: What is a warranty?
# A: An assurance that a product or service will perform to a certain standard
#
# ==================================================
#
# Q: What are some of the services that you use?
# A:
# Docs, Sheets, and Slides
#
# ==================================================

# %%
import nltk

try:
    sentences = nltk.sent_tokenize(document_text)
except LookupError:
    print("Downloading 'punkt_tab' data...")
    nltk.download('punkt_tab')
    sentences = nltk.sent_tokenize(document_text)

# combine sentences into passages
passages = []
current_passage = ""
for sentence in sentences:
    if len(current_passage.split()) + len(sentence.split()) < 20:  # adjust the word limit as needed
        current_passage += " " + sentence
    else:
        passages.append(current_passage.strip())
        current_passage = sentence  # Start a new passage with the current sentence

# Ensure the last passage is added
if current_passage:
    passages.append(current_passage.strip())

# Remove empty passages from the list
passages = [passage for passage in passages if passage]  # This line filters out empty strings
