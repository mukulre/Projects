# %% [markdown]
# <a href="https://colab.research.google.com/github/mukulre/Projects/blob/main/CBAM_Attention_Mechanism_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow-addons

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (Input, Conv2D, MaxPooling2D, Dense, Dropout,
                                     GlobalAveragePooling2D, GlobalMaxPooling2D,
                                     Reshape, Multiply, Add, Activation,
                                     Concatenate, BatchNormalization, Lambda)
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.utils import class_weight
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os

# ✅ CBAM Attention Block
def channel_attention(input_feature, reduction_ratio=8):
    channel = input_feature.shape[-1]
    shared_dense_one = Dense(channel // reduction_ratio, activation='relu', kernel_initializer='he_normal', use_bias=True)
    shared_dense_two = Dense(channel, kernel_initializer='he_normal', use_bias=True)

    avg_pool = GlobalAveragePooling2D()(input_feature)
    avg_pool = Reshape((1, 1, channel))(avg_pool)
    avg_out = shared_dense_two(shared_dense_one(avg_pool))

    max_pool = GlobalMaxPooling2D()(input_feature)
    max_pool = Reshape((1, 1, channel))(max_pool)
    max_out = shared_dense_two(shared_dense_one(max_pool))

    scale = Add()([avg_out, max_out])
    scale = Activation('sigmoid')(scale)

    return Multiply()([input_feature, scale])

def spatial_attention(input_feature):
    avg_pool = Lambda(lambda x: tf.reduce_mean(x, axis=-1, keepdims=True))(input_feature)
    max_pool = Lambda(lambda x: tf.reduce_max(x, axis=-1, keepdims=True))(input_feature)
    concat = Concatenate(axis=-1)([avg_pool, max_pool])
    cbam_feature = Conv2D(filters=1, kernel_size=7, padding='same', activation='sigmoid')(concat)
    return Multiply()([input_feature, cbam_feature])

def cbam_block(input_feature, reduction_ratio=8):
    x = channel_attention(input_feature, reduction_ratio)
    x = spatial_attention(x)
    return x

# ✅ Build Optimized CBAM CNN Model
def build_cbam_cnn(input_shape=(224, 224, 3)):
    inputs = Input(shape=input_shape)

    def conv_block(x, filters):
        x = Conv2D(filters, (3, 3), padding='same', kernel_initializer='he_normal')(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        x = MaxPooling2D((2, 2))(x)
        x = cbam_block(x)
        return x

    x = conv_block(inputs, 64)
    x = conv_block(x, 128)
    x = conv_block(x, 256)

    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.5)(x)
    outputs = Dense(1, activation='sigmoid')(x)

    return Model(inputs, outputs)

# ✅ Paths
train_path = '/content/drive/MyDrive/Pneumonia Detection/chest_xray/train'
val_path = '/content/drive/MyDrive/Pneumonia Detection/chest_xray/val'
test_path = '/content/drive/MyDrive/Pneumonia Detection/chest_xray/test'

# ✅ Data Generators
train_gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=25,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)
val_test_gen = ImageDataGenerator(rescale=1./255)

train_data = train_gen.flow_from_directory(train_path, target_size=(224, 224), batch_size=32, class_mode='binary')
val_data = val_test_gen.flow_from_directory(val_path, target_size=(224, 224), batch_size=32, class_mode='binary')
test_data = val_test_gen.flow_from_directory(test_path, target_size=(224, 224), batch_size=32, class_mode='binary', shuffle=False)

# ✅ Class Weights
class_weights = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.unique(train_data.classes),
    y=train_data.classes
)
class_weights = dict(enumerate(class_weights))

# ✅ Callbacks
early_stop = EarlyStopping(monitor='val_loss', patience=8, restore_best_weights=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=4, verbose=1)
checkpoint = ModelCheckpoint('best_cbam_model.h5', save_best_only=True, monitor='val_loss', verbose=1)

# ✅ Compile Model with AdamW Optimizer
model = build_cbam_cnn()
optimizer = Adam(learning_rate=0.0005, weight_decay=1e-5)

model.compile(optimizer=optimizer,
              loss='binary_crossentropy',
              metrics=['accuracy'])

# ✅ Train Model
history = model.fit(train_data,
                    validation_data=val_data,
                    epochs=50,
                    class_weight=class_weights,
                    callbacks=[early_stop, reduce_lr, checkpoint])

# ✅ Evaluation
loss, acc = model.evaluate(test_data)
print(f"\nTest Accuracy: {acc:.4f}")

# ✅ Save Final Model
model.save("cbam_cnn_final_model.h5")

# ✅ Visualization Functions
def plot_training(history):
    plt.figure(figsize=(14, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train Accuracy', linewidth=2)
    plt.plot(history.history['val_accuracy'], label='Val Accuracy', linewidth=2)
    plt.title("Accuracy per Epoch")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.grid(True)
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss', linewidth=2)
    plt.plot(history.history['val_loss'], label='Val Loss', linewidth=2)
    plt.title("Loss per Epoch")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.grid(True)
    plt.legend()

    plt.tight_layout()
    plt.show()

def plot_conf_matrix(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=['Normal', 'Pneumonia'],
                yticklabels=['Normal', 'Pneumonia'])
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title("Confusion Matrix")
    plt.tight_layout()
    plt.show()

def plot_roc_curve(y_true, y_probs):
    fpr, tpr, _ = roc_curve(y_true, y_probs)
    auc_score = auc(fpr, tpr)
    plt.figure(figsize=(6, 5))
    plt.plot(fpr, tpr, label=f"AUC = {auc_score:.2f}", linewidth=2)
    plt.plot([0, 1], [0, 1], 'k--', label="Random")
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title("ROC Curve")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# ✅ Metrics & Plots
y_true = test_data.classes
y_probs = model.predict(test_data).ravel()
y_pred = (y_probs > 0.5).astype(int)

plot_training(history)
plot_conf_matrix(y_true, y_pred)
plot_roc_curve(y_true, y_probs)

print("\nClassification Report:\n", classification_report(y_true, y_pred, target_names=["Normal", "Pneumonia"]))
# Out:
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.11/dist-packages (0.23.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow-addons) (24.2)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /usr/local/lib/python3.11/dist-packages (from tensorflow-addons) (2.13.3)
# Found 5216 images belonging to 2 classes.
# Found 16 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 719ms/step - accuracy: 0.6992 - loss: 0.5312
# Epoch 1: val_loss improved from inf to 3.02646, saving model to best_cbam_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 139s 743ms/step - accuracy: 0.6997 - loss: 0.5305 - val_accuracy: 0.5000 - val_loss: 3.0265 - learning_rate: 5.0000e-04
# Epoch 2/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 717ms/step - accuracy: 0.8727 - loss: 0.3095
# Epoch 2: val_loss did not improve from 3.02646
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 117s 719ms/step - accuracy: 0.8727 - loss: 0.3095 - val_accuracy: 0.5000 - val_loss: 3.8835 - learning_rate: 5.0000e-04
# Epoch 3/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 718ms/step - accuracy: 0.8804 - loss: 0.2646
# Epoch 3: val_loss did not improve from 3.02646
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 117s 719ms/step - accuracy: 0.8804 - loss: 0.2647 - val_accuracy: 0.5625 - val_loss: 3.1940 - learning_rate: 5.0000e-04
# Epoch 4/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 717ms/step - accuracy: 0.8823 - loss: 0.2813
# Epoch 4: val_loss improved from 3.02646 to 0.42842, saving model to best_cbam_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 117s 720ms/step - accuracy: 0.8823 - loss: 0.2812 - val_accuracy: 0.7500 - val_loss: 0.4284 - learning_rate: 5.0000e-04
# Epoch 5/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 707ms/step - accuracy: 0.8982 - loss: 0.2376
# Epoch 5: val_loss did not improve from 0.42842
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 116s 708ms/step - accuracy: 0.8982 - loss: 0.2376 - val_accuracy: 0.5000 - val_loss: 0.7535 - learning_rate: 5.0000e-04
# Epoch 6/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 710ms/step - accuracy: 0.8804 - loss: 0.2702
# Epoch 6: val_loss improved from 0.42842 to 0.36852, saving model to best_cbam_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 117s 712ms/step - accuracy: 0.8804 - loss: 0.2701 - val_accuracy: 0.8750 - val_loss: 0.3685 - learning_rate: 5.0000e-04
# Epoch 7/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 714ms/step - accuracy: 0.8933 - loss: 0.2442
# Epoch 7: val_loss did not improve from 0.36852
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 117s 715ms/step - accuracy: 0.8933 - loss: 0.2442 - val_accuracy: 0.5625 - val_loss: 0.7601 - learning_rate: 5.0000e-04
# Epoch 8/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 717ms/step - accuracy: 0.8896 - loss: 0.2425
# Epoch 8: val_loss did not improve from 0.36852
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 117s 719ms/step - accuracy: 0.8897 - loss: 0.2423 - val_accuracy: 0.6250 - val_loss: 1.3532 - learning_rate: 5.0000e-04
# Epoch 9/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 717ms/step - accuracy: 0.9085 - loss: 0.2054
# Epoch 9: val_loss did not improve from 0.36852
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 117s 718ms/step - accuracy: 0.9085 - loss: 0.2054 - val_accuracy: 0.8125 - val_loss: 0.4400 - learning_rate: 5.0000e-04
# Epoch 10/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 734ms/step - accuracy: 0.9120 - loss: 0.2094
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 10: val_loss did not improve from 0.36852
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 120s 735ms/step - accuracy: 0.9120 - loss: 0.2094 - val_accuracy: 0.6250 - val_loss: 0.6447 - learning_rate: 5.0000e-04
# Epoch 11/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 711ms/step - accuracy: 0.9126 - loss: 0.1968
# Epoch 11: val_loss did not improve from 0.36852
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 116s 712ms/step - accuracy: 0.9126 - loss: 0.1967 - val_accuracy: 0.8125 - val_loss: 0.4860 - learning_rate: 2.5000e-04
# Epoch 12/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9267 - loss: 0.1766
# Epoch 12: val_loss did not improve from 0.36852
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 142s 710ms/step - accuracy: 0.9267 - loss: 0.1766 - val_accuracy: 0.6250 - val_loss: 0.6309 - learning_rate: 2.5000e-04
# Epoch 13/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 711ms/step - accuracy: 0.9215 - loss: 0.1852
# Epoch 13: val_loss improved from 0.36852 to 0.35737, saving model to best_cbam_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 117s 714ms/step - accuracy: 0.9215 - loss: 0.1851 - val_accuracy: 0.8125 - val_loss: 0.3574 - learning_rate: 2.5000e-04
# Epoch 14/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 718ms/step - accuracy: 0.9203 - loss: 0.1857
# Epoch 14: val_loss did not improve from 0.35737
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 117s 720ms/step - accuracy: 0.9203 - loss: 0.1857 - val_accuracy: 0.8125 - val_loss: 0.4292 - learning_rate: 2.5000e-04
# Epoch 15/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 721ms/step - accuracy: 0.9184 - loss: 0.1842
# Epoch 15: val_loss did not improve from 0.35737
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 118s 722ms/step - accuracy: 0.9184 - loss: 0.1842 - val_accuracy: 0.6875 - val_loss: 0.6804 - learning_rate: 2.5000e-04
# Epoch 16/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 722ms/step - accuracy: 0.9339 - loss: 0.1518
# Epoch 16: val_loss did not improve from 0.35737
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 118s 723ms/step - accuracy: 0.9339 - loss: 0.1519 - val_accuracy: 0.6250 - val_loss: 3.3684 - learning_rate: 2.5000e-04
# Epoch 17/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 720ms/step - accuracy: 0.9305 - loss: 0.1625
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 17: val_loss did not improve from 0.35737
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 118s 722ms/step - accuracy: 0.9305 - loss: 0.1625 - val_accuracy: 0.8125 - val_loss: 0.4730 - learning_rate: 2.5000e-04
# Epoch 18/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 723ms/step - accuracy: 0.9360 - loss: 0.1583
# Epoch 18: val_loss did not improve from 0.35737
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 119s 727ms/step - accuracy: 0.9360 - loss: 0.1582 - val_accuracy: 0.6250 - val_loss: 1.2763 - learning_rate: 1.2500e-04
# Epoch 19/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9424 - loss: 0.1441
# Epoch 19: val_loss did not improve from 0.35737
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 143s 731ms/step - accuracy: 0.9423 - loss: 0.1441 - val_accuracy: 0.6875 - val_loss: 0.4811 - learning_rate: 1.2500e-04
# Epoch 20/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9375 - loss: 0.1473
# Epoch 20: val_loss did not improve from 0.35737
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 119s 730ms/step - accuracy: 0.9375 - loss: 0.1473 - val_accuracy: 0.6250 - val_loss: 2.4014 - learning_rate: 1.2500e-04
# Epoch 21/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 720ms/step - accuracy: 0.9389 - loss: 0.1490
# Epoch 21: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 21: val_loss did not improve from 0.35737
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 141s 722ms/step - accuracy: 0.9389 - loss: 0.1490 - val_accuracy: 0.7500 - val_loss: 0.3915 - learning_rate: 1.2500e-04
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 13.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 273ms/step - accuracy: 0.8612 - loss: 0.3437
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Test Accuracy: 0.8013
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 409ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#       Normal       0.68      0.90      0.77       234
#    Pneumonia       0.93      0.74      0.82       390
#
#     accuracy                           0.80       624
#    macro avg       0.80      0.82      0.80       624
# weighted avg       0.83      0.80      0.80       624
